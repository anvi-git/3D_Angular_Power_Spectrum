# %% [markdown]
# # Beyond BLAST

# %%
ENV["JULIA_PKG_PRECOMPILE_AUTO"] = 0;
using Pkg
Pkg.activate("blast_code"; io=devnull)
Pkg.resolve(; io=devnull)
Pkg.instantiate(; io=devnull)

using Base.Threads
using NPZ
using DataInterpolations
using Interpolations
using FastChebInterp
using BenchmarkTools
using FFTW
using FastTransforms
using Dates
using TOML
using Plots
using Plots.Measures
using QuadGK
using LaTeXStrings
using Tullio
using StaticArrays
using LoopVectorization
using LinearAlgebra
using Unitful
using Revise
using SpecialFunctions
using DifferentialEquations
using Cosmology
using NumericalIntegration
using CSV
using DataFrames
using JSON
# Out:
# [ Info: Precompiling DataInterpolations [82cc6244-b520-54b8-b5a6-8a565e85f1d0]
# Precompiling packages...
#    2009.9 ms  ✓ DataInterpolations → DataInterpolationsChainRulesCoreExt
#   1 dependency successfully precompiled in 3 seconds. 37 already precompiled.
# [ Info: Precompiling DataInterpolationsChainRulesCoreExt [187dfacc-d000-5da0-94aa-5ec8eb045cfd]
# ┌ Warning: Module DataInterpolations with build ID fafbfcfd-acc8-7675-9f0a-ac0cd5c7d708 is missing from the cache.
# │ This may mean DataInterpolations [82cc6244-b520-54b8-b5a6-8a565e85f1d0] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:2022
# [ Info: Skipping precompilation since __precompile__(false). Importing DataInterpolationsChainRulesCoreExt [187dfacc-d000-5da0-94aa-5ec8eb045cfd].
# Precompiling packages...
#     644.4 ms  ✓ FastChebInterp
#   1 dependency successfully precompiled in 1 seconds. 18 already precompiled.
# [ Info: Precompiling FastChebInterp [cf66c380-9a80-432c-aff8-4f9c79c0bdde]
# Precompiling packages...
#    1054.6 ms  ✓ FastTransforms_jll
#    5011.3 ms  ✓ Polynomials → PolynomialsFFTWExt
#    5084.6 ms  ✓ GenericFFT
#    1823.4 ms  ✓ DSP
#    1326.6 ms  ✓ ToeplitzMatrices
#    5422.9 ms  ✓ FastTransforms
#   6 dependencies successfully precompiled in 14 seconds. 52 already precompiled.
# [ Info: Precompiling FastTransforms [057dd010-8810-581a-b7be-e3fc3b93f78c]
# ┌ Warning: Module FFTW with build ID fafbfcfd-9036-ec41-e7d7-078d43f1ff78 is missing from the cache.
# │ This may mean FFTW [7a1cc6ca-52ef-59f5-83cd-3a7055c09341] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:2022
# [ Info: Skipping precompilation since __precompile__(false). Importing FastTransforms [057dd010-8810-581a-b7be-e3fc3b93f78c].
# [ Info: Precompiling ToeplitzMatrices [c751599d-da0a-543b-9d20-d0a503d91d24]
# ┌ Warning: Module FFTW with build ID fafbfcfd-9036-ec41-e7d7-078d43f1ff78 is missing from the cache.
# │ This may mean FFTW [7a1cc6ca-52ef-59f5-83cd-3a7055c09341] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:2022
# [ Info: Skipping precompilation since __precompile__(false). Importing ToeplitzMatrices [c751599d-da0a-543b-9d20-d0a503d91d24].
# [ Info: Precompiling DSP [717857b8-e6f2-59f4-9121-6e50c889abd2]
# ┌ Warning: Module FFTW with build ID fafbfcfd-9036-ec41-e7d7-078d43f1ff78 is missing from the cache.
# │ This may mean FFTW [7a1cc6ca-52ef-59f5-83cd-3a7055c09341] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:2022
# [ Info: Skipping precompilation since __precompile__(false). Importing DSP [717857b8-e6f2-59f4-9121-6e50c889abd2].
# [ Info: Precompiling PolynomialsFFTWExt [9608b13c-6431-545a-872b-73fbdae89308]
# ┌ Warning: Module FFTW with build ID fafbfcfd-9036-ec41-e7d7-078d43f1ff78 is missing from the cache.
# │ This may mean FFTW [7a1cc6ca-52ef-59f5-83cd-3a7055c09341] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:2022
# [ Info: Skipping precompilation since __precompile__(false). Importing PolynomialsFFTWExt [9608b13c-6431-545a-872b-73fbdae89308].
# Precompiling packages...
#     704.4 ms  ✓ DSP → OffsetArraysExt
#   1 dependency successfully precompiled in 1 seconds. 32 already precompiled.
# [ Info: Precompiling OffsetArraysExt [02126f2d-06e7-5683-ad72-625195948cc6]
# ┌ Warning: Module DSP with build ID ffffffff-ffff-ffff-fcd3-6e5a7ab3134f is missing from the cache.
# │ This may mean DSP [717857b8-e6f2-59f4-9121-6e50c889abd2] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:2022
# [ Info: Skipping precompilation since __precompile__(false). Importing OffsetArraysExt [02126f2d-06e7-5683-ad72-625195948cc6].
# [ Info: Precompiling GenericFFT [a8297547-1b15-4a5a-a998-a2ac5f1cef28]
# ┌ Warning: Module FFTW with build ID fafbfcfd-9036-ec41-e7d7-078d43f1ff78 is missing from the cache.
# │ This may mean FFTW [7a1cc6ca-52ef-59f5-83cd-3a7055c09341] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:2022
# [ Info: Skipping precompilation since __precompile__(false). Importing GenericFFT [a8297547-1b15-4a5a-a998-a2ac5f1cef28].
# [ Info: Precompiling FastTransforms_jll [34b6f7d7-08f9-5794-9e10-3819e4c7e49a]
# ┌ Warning: Module FFTW_jll with build ID fafbfcfd-370a-49de-bffe-a7ae1a926d71 is missing from the cache.
# │ This may mean FFTW_jll [f5851436-0d7a-5f13-b9de-f02708fd171a] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:2022
# [ Info: Skipping precompilation since __precompile__(false). Importing FastTransforms_jll [34b6f7d7-08f9-5794-9e10-3819e4c7e49a].
# [ Info: Precompiling Plots [91a5bcdd-55d7-5caf-9e0b-520d859cae80]
# Precompiling packages...
#     819.0 ms  ✓ ToeplitzMatrices → ToeplitzMatricesStatsBaseExt
#   1 dependency successfully precompiled in 1 seconds. 43 already precompiled.
# [ Info: Precompiling ToeplitzMatricesStatsBaseExt [10c45357-b3b9-5a2a-8cf3-003d4462209a]
# ┌ Warning: Module ToeplitzMatrices with build ID ffffffff-ffff-ffff-2d7f-8e7abe84b118 is missing from the cache.
# │ This may mean ToeplitzMatrices [c751599d-da0a-543b-9d20-d0a503d91d24] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:2022
# [ Info: Skipping precompilation since __precompile__(false). Importing ToeplitzMatricesStatsBaseExt [10c45357-b3b9-5a2a-8cf3-003d4462209a].
# Precompiling packages...
#    1484.4 ms  ✓ Ghostscript_jll
#    1691.6 ms  ✓ OpenSSL
#    1767.2 ms  ✓ Latexify
#    1099.0 ms  ✓ Latexify → SparseArraysExt
#    6600.9 ms  ✓ Pango_jll
#    7560.5 ms  ✓ Qt6ShaderTools_jll
#    7572.5 ms  ✓ Qt6Svg_jll
#    1960.4 ms  ✓ Qt6Declarative_jll
#    8754.5 ms  ✓ HTTP
#    8108.0 ms  ✓ GR → IJuliaExt
#   34156.6 ms  ✓ Plots → IJuliaExt
#   11 dependencies successfully precompiled in 45 seconds. 146 already precompiled.
# [ Info: Precompiling IJuliaExt [64482eec-cc57-5312-bea1-9f24eb636db7]
# ┌ Warning: Module GR with build ID fafbfcfd-0f32-225f-98f4-f3e1a7411861 is missing from the cache.
# │ This may mean GR [28b8d3ca-fb5f-59d9-8090-bfdbd6d07a71] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:2022
# [ Info: Skipping precompilation since __precompile__(false). Importing IJuliaExt [64482eec-cc57-5312-bea1-9f24eb636db7].
# ┌ Warning: The call to compilecache failed to create a usable precompiled cache file for Plots [91a5bcdd-55d7-5caf-9e0b-520d859cae80]
# │   exception = Invalid input in module list: expected JLLWrappers.
# └ @ Base loading.jl:2076
# Precompiling packages...
#     769.4 ms  ✓ FileIO → HTTPExt
#    1385.9 ms  ✓ Plots → FileIOExt
#   2 dependencies successfully precompiled in 2 seconds. 150 already precompiled.
# [ Info: Precompiling FileIOExt [f5f51d8f-5827-5d2e-939b-192fcd6ec70c]
# ┌ Warning: Module Plots with build ID ffffffff-ffff-ffff-5434-42b905a5d8c2 is missing from the cache.
# │ This may mean Plots [91a5bcdd-55d7-5caf-9e0b-520d859cae80] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:2022
# [ Info: Skipping precompilation since __precompile__(false). Importing FileIOExt [f5f51d8f-5827-5d2e-939b-192fcd6ec70c].
# [ Info: Precompiling IJuliaExt [2f4121a4-3b3a-5ce6-9c5e-1f2673ce168a]
# ┌ Warning: Module Plots with build ID ffffffff-ffff-ffff-5434-42b905a5d8c2 is missing from the cache.
# │ This may mean Plots [91a5bcdd-55d7-5caf-9e0b-520d859cae80] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:2022
# [ Info: Skipping precompilation since __precompile__(false). Importing IJuliaExt [2f4121a4-3b3a-5ce6-9c5e-1f2673ce168a].
# Precompiling packages...
#     515.9 ms  ✓ Unitful → LatexifyExt
#    2419.6 ms  ✓ Plots → UnitfulExt
#   2 dependencies successfully precompiled in 3 seconds. 166 already precompiled.
# [ Info: Precompiling UnitfulExt [0e51ec96-f580-5f12-a625-1297083d7970]
# ┌ Warning: Module Plots with build ID ffffffff-ffff-ffff-5434-42b905a5d8c2 is missing from the cache.
# │ This may mean Plots [91a5bcdd-55d7-5caf-9e0b-520d859cae80] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:2022
# [ Info: Skipping precompilation since __precompile__(false). Importing UnitfulExt [0e51ec96-f580-5f12-a625-1297083d7970].
# [ Info: Precompiling Latexify [23fbe1c1-3f47-55db-b15f-69d7ec21a316]
# ┌ Warning: Module JpegTurbo_jll with build ID fafbfcfd-bbf0-e828-cb81-17b2b71a976b is missing from the cache.
# │ This may mean JpegTurbo_jll [aacddb02-875f-59d6-b918-886e6ef4fbf8] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:2022
# [ Info: Skipping precompilation since __precompile__(false). Importing Latexify [23fbe1c1-3f47-55db-b15f-69d7ec21a316].
# [ Info: Precompiling Ghostscript_jll [61579ee1-b43e-5ca0-a5da-69d92c66a64b]
# ┌ Warning: Module JpegTurbo_jll with build ID fafbfcfd-bbf0-e828-cb81-17b2b71a976b is missing from the cache.
# │ This may mean JpegTurbo_jll [aacddb02-875f-59d6-b918-886e6ef4fbf8] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:2022
# [ Info: Skipping precompilation since __precompile__(false). Importing Ghostscript_jll [61579ee1-b43e-5ca0-a5da-69d92c66a64b].
# [ Info: Precompiling SparseArraysExt [b89a79fa-fa5a-56f8-98ad-0d55ac4e0ff2]
# ┌ Warning: Module Latexify with build ID ffffffff-ffff-ffff-eebf-f154968d01f6 is missing from the cache.
# │ This may mean Latexify [23fbe1c1-3f47-55db-b15f-69d7ec21a316] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:2022
# [ Info: Skipping precompilation since __precompile__(false). Importing SparseArraysExt [b89a79fa-fa5a-56f8-98ad-0d55ac4e0ff2].
# [ Info: Precompiling LatexifyExt [62c8d523-959e-58eb-864b-07d8b3b537d5]
# ┌ Warning: Module Latexify with build ID ffffffff-ffff-ffff-eebf-f154968d01f6 is missing from the cache.
# │ This may mean Latexify [23fbe1c1-3f47-55db-b15f-69d7ec21a316] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:2022
# [ Info: Skipping precompilation since __precompile__(false). Importing LatexifyExt [62c8d523-959e-58eb-864b-07d8b3b537d5].
# [ Info: Precompiling DataFramesExt [9e668153-f473-5010-85ff-a85cbe3b95ea]
# ┌ Warning: Module Latexify with build ID ffffffff-ffff-ffff-eebf-f154968d01f6 is missing from the cache.
# │ This may mean Latexify [23fbe1c1-3f47-55db-b15f-69d7ec21a316] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:2022
# [ Info: Skipping precompilation since __precompile__(false). Importing DataFramesExt [9e668153-f473-5010-85ff-a85cbe3b95ea].

# %%
include("blast_code/src/Blast.jl")
include("blast_code/src/blast_tutorials.jl")
using .Blast
using .blast_tutorials;
include("blast_code/src/galaxy_galaxy.jl")
#include("blast_code/src/galaxy_shear.jl")
include("blast_code/src/shear_shear.jl")
using .galaxy_galaxy
#using .galaxy_shear
using .shear_shear

# %%
timestamp = Dates.format(now(), "yyyy_mm_dd_HHMMSS")
output_dir = "out/runs/run_$timestamp"
plot_subdir = joinpath(output_dir, "plots")
Sl_plots = joinpath(plot_subdir, "Sl_plots")
Kernel_plots = joinpath(plot_subdir, "kernels")
quantity_subdir = joinpath(output_dir, "quantities")
chebcoefs = joinpath(quantity_subdir, "chebcoefs")
Sl = joinpath(quantity_subdir, "Sl")
mkpath(output_dir)
mkpath(plot_subdir)
mkpath(quantity_subdir)
mkpath(chebcoefs)
mkpath(Sl)
mkpath(Sl_plots)
mkpath(Kernel_plots)
println("Folders in place: ", output_dir, ", ", plot_subdir, " and ", quantity_subdir)
# Out:
# Folders in place: out/runs/run_2026_06_20_120050, out/runs/run_2026_06_20_120050/plots and out/runs/run_2026_06_20_120050/quantities

# %% [markdown]
# ### Getting background quantities:
#
# redshift $z$, comoving distance $\chi(z)$

# %%
#Background quantities
z_b = npzread("blast_code/data/background/z.npy") # array 
χ_b = npzread("blast_code/data/background/chi.npy") # array 
# using Akima interpolation
z_of_χ = DataInterpolations.AkimaInterpolation(z_b, χ_b); # z(χ)
chi_of_z = DataInterpolations.AkimaInterpolation(χ_b, z_b); # χ(z)

# %% [markdown]
# #### Setting parameters

# %%
cosmo = Blast.FlatΛCDM()
n_chi = 96                                            # Number of comoving distance points
x_range = LinRange(26, 7000, n_chi)                   # in Mpc/h: from 26 Mpc/h to 7000 Mpc/h
z_range = z_of_χ.(x_range)
#ℓ = Blast.ℓ
ℓ = LinRange(2, 200, 100)
x_min = minimum(x_range)                              # minimum comoving distance [Mpc/h]
x_max = maximum(x_range)                              # maximum comoving distance [Mpc/h]
chi = LinRange(x_min, x_max, n_chi)                   # array of comoving distances [Mpc/h]
zed = z_of_χ.(chi)                                    # array of redshifts corresponding to the comoving distances
n_z = length(zed)
n5k_bins = npzread("blast_code/data/dNdzs_fullwidth.npz")
z_n5k = n5k_bins["z_cl"]
zmin = minimum(z_n5k)                                 # minimum redshift
zmax = maximum(z_n5k)                                 # maximum redshift
kmax = 200/13                                         # maximum wavenumber (small scales) [h/Mpc]
kmin = 2.5/x_max                                      # minimum wavenumber (large scales) [h/Mpc]
n_cheb = 119                                          # number of Chebyshev nodes 
β = 2                                                 # exponent depending on the probe: 0 for Galaxy - Shear, 2 for Galaxy - Galaxy, -2 for Shear - Shear
k_cheb = chebpoints(n_cheb, log10(kmin), log10(kmax)) # number of Chebyshev "points"
N = 2^15+1;

# %%
shear_prefac_W = shear_shear.shear_prefactor(x_range, z_range, cosmo; output_dir=output_dir);
shear_prefac_W_cheb = shear_shear.shear_prefactor_cheb(zmin, zmax, n_cheb, z_range, shear_prefac_W; output_dir=output_dir);
cheb_coeff_shear = shear_shear.compute_prefactor_chebcoeffs(shear_prefac_W_cheb; output_dir=output_dir);
# Out:
# Plot saved: out/runs/run_2026_06_20_120050/plots/kernels/chi_vs_z_shear.png
# Plot saved: out/runs/run_2026_06_20_120050/plots/kernels/nz_shear.png
# Plot saved: out/runs/run_2026_06_20_120050/plots/kernels/lensing_efficiency.png
# Wrote W(z) shear prefactor on Chebyshev grid to: out/runs/run_2026_06_20_120050/quantities/prefac_on_cheb_shear.npy
# Wrote W(z) Chebyshev coefficients to: out/runs/run_2026_06_20_120050/quantities/W_cheb_coeff_shear.npy

# %% [markdown]
# Defining the kernel/window function for a galaxy probe: the window function is \
# \
# $W(z) = n(z) \chi(z)^2 b(z) D(z) $ \
# \
# where \
# \
# $n(z) = A (\frac{z}{z_0})^{\alpha} exp[{-(\frac{z}{z_0})^{\beta}}] $, with $A = \frac{1.5}{z_0}$, $\alpha = 2$ and $\beta = 1.5$ \
# \
# $b(z) = b_0 \sqrt{1+z} $ and $b_0 = 1$ \
# \
# $D(z) = \frac{D(z)^{unnorm}}{D(0)^{unnorm}}$, with $D(z)^{unnorm} = E(z) \int_0^{\infty} dz' \frac{1+z'}{E(z')^3} $

# %%
gal_prefact_W, bias, growth, inv_Hubble, nz_norm = galaxy_galaxy.galaxy_prefactor(x_range, z_range, cosmo; output_dir=output_dir);
gal_prefact_W_cheb = galaxy_galaxy.galaxy_prefactor_cheb(zmin, zmax, n_cheb, z_range, chi, bias, growth, inv_Hubble, nz_norm; output_dir=output_dir);
cheb_coeff_gal = galaxy_galaxy.compute_prefactor_chebcoeffs(gal_prefact_W_cheb; output_dir=output_dir);
# Out:
# Plot saved: out/runs/run_2026_06_20_120050/plots/kernels/chi_vs_z.png
# Plot saved: out/runs/run_2026_06_20_120050/plots/kernels/bias.png
# Plot saved: out/runs/run_2026_06_20_120050/plots/kernels/growth.png
# Plot saved: out/runs/run_2026_06_20_120050/plots/kernels/inv_hubble.png
# Plot saved: out/runs/run_2026_06_20_120050/plots/kernels/nz.png
# Plot saved: out/runs/run_2026_06_20_120050/plots/kernels/Wz.png
# Plot saved: out/runs/run_2026_06_20_120050/plots/kernels/normalized_kernel_galaxy.png
# Plot saved: out/runs/run_2026_06_20_120050/plots/kernels/unnormalized_kernel_galaxy.png
# Wrote W(z) prefactor to: out/runs/run_2026_06_20_120050/quantities/prefac_galaxy.npy
# Wrote W(z) prefactor on Chebyshev grid to: out/runs/run_2026_06_20_120050/quantities/prefac_on_cheb_galaxy.npy
# Wrote W(z) Chebyshev coefficients to: out/runs/run_2026_06_20_120050/quantities/W_cheb_coeff_galaxy.npy

# %%
println("Size of cheb_coeffs must be the same for shear and galaxy")
println("size of cheb_coeff_shear: ", size(cheb_coeff_shear))
println("size of cheb_coeff_gal: ", size(cheb_coeff_gal))
# Out:
# Size of cheb_coeffs must be the same for shear and galaxy
# size of cheb_coeff_shear: (119,)
# size of cheb_coeff_gal: (119,)

# %%
W_tilde_gg = zeros(length(ℓ), length(z_range), length(z_range), n_cheb)
W_tilde_ss = zeros(length(ℓ), length(z_range), length(z_range), n_cheb)
for i in eachindex(ℓ)
    W_tilde_gg[i,:,:,:] = Blast.new_compute_W_tilde(ℓ[i], zmin, zmax, kmin, kmax, 2, z_range, n_cheb - 1, N, chi_of_z)
    W_tilde_ss[i,:,:,:] = Blast.new_compute_W_tilde(ℓ[i], zmin, zmax, kmin, kmax, -2, z_range, n_cheb - 1, N, chi_of_z)
    println("Finished computing W_tilde for ℓ = $(ℓ[i]) at $(Dates.now())")
end
# Out:
# Finished computing W_tilde for ℓ = 2.0 at 2026-06-20T12:04:13.091
# Finished computing W_tilde for ℓ = 4.0 at 2026-06-20T12:04:54.551
# Finished computing W_tilde for ℓ = 6.0 at 2026-06-20T12:05:35.723
# Finished computing W_tilde for ℓ = 8.0 at 2026-06-20T12:06:16.741
# Finished computing W_tilde for ℓ = 10.0 at 2026-06-20T12:06:59.843
# Finished computing W_tilde for ℓ = 12.0 at 2026-06-20T12:07:40.058
# Finished computing W_tilde for ℓ = 14.0 at 2026-06-20T12:08:21.051
# Finished computing W_tilde for ℓ = 15.999999999999998 at 2026-06-20T12:09:02.384
# Finished computing W_tilde for ℓ = 18.0 at 2026-06-20T12:09:44.063
# Finished computing W_tilde for ℓ = 20.0 at 2026-06-20T12:10:26.317
# Finished computing W_tilde for ℓ = 22.0 at 2026-06-20T12:11:11.365
# Finished computing W_tilde for ℓ = 24.0 at 2026-06-20T12:11:59.874
# Finished computing W_tilde for ℓ = 26.0 at 2026-06-20T12:12:51.064
# Finished computing W_tilde for ℓ = 28.000000000000004 at 2026-06-20T12:13:45.343
# Finished computing W_tilde for ℓ = 29.999999999999996 at 2026-06-20T12:14:42.805
# Finished computing W_tilde for ℓ = 32.0 at 2026-06-20T12:15:39.653
# Finished computing W_tilde for ℓ = 34.0 at 2026-06-20T12:16:41.525
# Finished computing W_tilde for ℓ = 35.99999999999999 at 2026-06-20T12:17:46.495
# Finished computing W_tilde for ℓ = 38.0 at 2026-06-20T12:18:52.107
# Finished computing W_tilde for ℓ = 40.0 at 2026-06-20T12:19:59.277
# Finished computing W_tilde for ℓ = 42.0 at 2026-06-20T12:21:07.946
# Finished computing W_tilde for ℓ = 44.0 at 2026-06-20T12:22:17.728
# Finished computing W_tilde for ℓ = 46.0 at 2026-06-20T12:23:26.974
# Finished computing W_tilde for ℓ = 48.0 at 2026-06-20T12:24:36.584
# Finished computing W_tilde for ℓ = 50.0 at 2026-06-20T12:25:47.649
# Finished computing W_tilde for ℓ = 52.0 at 2026-06-20T12:26:56.766
# Finished computing W_tilde for ℓ = 54.00000000000001 at 2026-06-20T12:28:07.017
# Finished computing W_tilde for ℓ = 55.99999999999999 at 2026-06-20T12:29:16.118
# Finished computing W_tilde for ℓ = 57.99999999999999 at 2026-06-20T12:30:25.290
# Finished computing W_tilde for ℓ = 60.0 at 2026-06-20T12:31:35.080
# Finished computing W_tilde for ℓ = 62.0 at 2026-06-20T12:32:44.685
# Finished computing W_tilde for ℓ = 64.0 at 2026-06-20T12:33:54.597
# Finished computing W_tilde for ℓ = 66.0 at 2026-06-20T12:35:04.857
# Finished computing W_tilde for ℓ = 67.99999999999999 at 2026-06-20T12:36:14.995
# Finished computing W_tilde for ℓ = 69.99999999999999 at 2026-06-20T12:37:26.591
# Finished computing W_tilde for ℓ = 72.0 at 2026-06-20T12:38:36.221
# Finished computing W_tilde for ℓ = 74.0 at 2026-06-20T12:39:46.109
# Finished computing W_tilde for ℓ = 76.0 at 2026-06-20T12:40:55.443
# Finished computing W_tilde for ℓ = 78.0 at 2026-06-20T12:42:04.451
# Finished computing W_tilde for ℓ = 80.0 at 2026-06-20T12:43:13.633
# Finished computing W_tilde for ℓ = 82.0 at 2026-06-20T12:44:23.146
# Finished computing W_tilde for ℓ = 84.0 at 2026-06-20T12:45:35.111
# Finished computing W_tilde for ℓ = 86.0 at 2026-06-20T12:46:46.312
# Finished computing W_tilde for ℓ = 88.00000000000001 at 2026-06-20T12:47:55.673
# Finished computing W_tilde for ℓ = 90.0 at 2026-06-20T12:49:02.802
# Finished computing W_tilde for ℓ = 92.0 at 2026-06-20T12:50:09.225
# Finished computing W_tilde for ℓ = 94.0 at 2026-06-20T12:51:15.097
# Finished computing W_tilde for ℓ = 96.0 at 2026-06-20T12:52:21.759
# Finished computing W_tilde for ℓ = 98.0 at 2026-06-20T12:53:33.508
# Finished computing W_tilde for ℓ = 100.0 at 2026-06-20T12:54:40.059
# Finished computing W_tilde for ℓ = 102.0 at 2026-06-20T12:55:47.168
# Finished computing W_tilde for ℓ = 104.0 at 2026-06-20T12:56:53.619
# Finished computing W_tilde for ℓ = 106.00000000000001 at 2026-06-20T12:58:01.015
# Finished computing W_tilde for ℓ = 108.0 at 2026-06-20T12:59:07.681
# Finished computing W_tilde for ℓ = 109.99999999999999 at 2026-06-20T13:00:15.369
# Finished computing W_tilde for ℓ = 112.0 at 2026-06-20T13:01:22.148
# Finished computing W_tilde for ℓ = 113.99999999999999 at 2026-06-20T13:02:28.331
# Finished computing W_tilde for ℓ = 116.0 at 2026-06-20T13:03:35.684
# Finished computing W_tilde for ℓ = 118.0 at 2026-06-20T13:04:42.926
# Finished computing W_tilde for ℓ = 119.99999999999999 at 2026-06-20T13:05:49.366
# Finished computing W_tilde for ℓ = 122.0 at 2026-06-20T13:06:54.751
# Finished computing W_tilde for ℓ = 123.99999999999999 at 2026-06-20T13:08:01.444
# Finished computing W_tilde for ℓ = 126.0 at 2026-06-20T13:09:08.303
# Finished computing W_tilde for ℓ = 128.0 at 2026-06-20T13:10:14.854
# Finished computing W_tilde for ℓ = 130.0 at 2026-06-20T13:11:22.349
# Finished computing W_tilde for ℓ = 132.0 at 2026-06-20T13:12:30.363
# Finished computing W_tilde for ℓ = 133.99999999999997 at 2026-06-20T13:13:35.581
# Finished computing W_tilde for ℓ = 136.0 at 2026-06-20T13:14:42.991
# Finished computing W_tilde for ℓ = 137.99999999999997 at 2026-06-20T13:15:49.395
# Finished computing W_tilde for ℓ = 140.0 at 2026-06-20T13:16:55.556
# Finished computing W_tilde for ℓ = 142.0 at 2026-06-20T13:18:04.336
# Finished computing W_tilde for ℓ = 143.99999999999997 at 2026-06-20T13:19:11.476
# Finished computing W_tilde for ℓ = 146.0 at 2026-06-20T13:20:20.340
# Finished computing W_tilde for ℓ = 147.99999999999997 at 2026-06-20T13:21:27.987
# Finished computing W_tilde for ℓ = 150.0 at 2026-06-20T13:22:35.268
# Finished computing W_tilde for ℓ = 152.0 at 2026-06-20T13:23:42.755
# Finished computing W_tilde for ℓ = 154.0 at 2026-06-20T13:24:49.562
# Finished computing W_tilde for ℓ = 156.00000000000003 at 2026-06-20T13:25:58.146
# Finished computing W_tilde for ℓ = 158.0 at 2026-06-20T13:27:06
# Finished computing W_tilde for ℓ = 160.00000000000003 at 2026-06-20T13:28:18.924
# Finished computing W_tilde for ℓ = 162.0 at 2026-06-20T13:29:30.921
# Finished computing W_tilde for ℓ = 164.00000000000003 at 2026-06-20T13:30:40.639
# Finished computing W_tilde for ℓ = 166.0 at 2026-06-20T13:31:49.086
# Finished computing W_tilde for ℓ = 168.0 at 2026-06-20T13:32:55.527
# Finished computing W_tilde for ℓ = 170.0 at 2026-06-20T13:34:01.825
# Finished computing W_tilde for ℓ = 172.0 at 2026-06-20T13:35:09.872
# Finished computing W_tilde for ℓ = 174.00000000000003 at 2026-06-20T13:36:17.596
# Finished computing W_tilde for ℓ = 176.0 at 2026-06-20T13:37:23.718
# Finished computing W_tilde for ℓ = 178.0 at 2026-06-20T13:38:31.561
# Finished computing W_tilde for ℓ = 180.0 at 2026-06-20T13:39:39.600
# Finished computing W_tilde for ℓ = 182.0 at 2026-06-20T13:40:46.756
# Finished computing W_tilde for ℓ = 184.0 at 2026-06-20T13:41:55.912
# Finished computing W_tilde for ℓ = 186.0 at 2026-06-20T13:43:05.876
# Finished computing W_tilde for ℓ = 188.0 at 2026-06-20T13:44:13.605
# Finished computing W_tilde for ℓ = 190.0 at 2026-06-20T13:45:21.133
# Finished computing W_tilde for ℓ = 192.0 at 2026-06-20T13:46:29.711
# Finished computing W_tilde for ℓ = 194.0 at 2026-06-20T13:47:39.745
# Finished computing W_tilde for ℓ = 196.0 at 2026-06-20T13:48:47.185
# Finished computing W_tilde for ℓ = 198.0 at 2026-06-20T13:49:55.262
# Finished computing W_tilde for ℓ = 200.0 at 2026-06-20T13:51:04.116

# %%
npzwrite(joinpath(output_dir, "W_tilde_gg.npy"), W_tilde_gg)
npzwrite(joinpath(output_dir, "W_tilde_ss.npy"), W_tilde_ss)

# %%
println("Size of W_tilde_gg: ", size(W_tilde_gg))
println("Size of W_tilde_ss: ", size(W_tilde_ss))
# Out:
# Size of W_tilde_gg: (100, 96, 96, 119)
# Size of W_tilde_ss: (100, 96, 96, 119)

# %% [markdown]
# $\tilde W(k,k_1)$ (like $\tilde W(k,k_1)$) represents the term: \
# $\tilde W_{i,p,l}^{(\ell)} = \sum_{m=1}^{N_k} w_{k_m} T_{\ell}(k_m) j_{\ell}(\chi_i k_m) j_{\ell}(\chi_p k_m) $ \
# it describes how much two shells at comoving distance $\chi_i$ and $\chi_p$ are correlated to the multipole $\ell$, weighted by the Chebyshev polynomial $T_{\ell}$ on the mode $k$.

# %%
npzwrite(joinpath(quantity_subdir, "chebcoefs/cheb_coeff_shear.npy"), cheb_coeff_shear)
npzwrite(joinpath(quantity_subdir, "chebcoefs/cheb_coeff_gal.npy"), cheb_coeff_gal)

# %%
@tullio W_final_gal[i, j, k] := W_tilde_gg[i, j, k, l] * cheb_coeff_gal[l];
@tullio W_final_shear[i, j, k] := W_tilde_ss[i, j, k, l] * cheb_coeff_shear[l];

# %%
npzwrite(joinpath(output_dir, "W_final_gal.npy"), W_final_gal)
npzwrite(joinpath(output_dir, "W_final_shear.npy"), W_final_shear)

# %%
#3D matter power spectrum
pk_dict = npzread("blast_code/data/pk.npz")
Pklin = pk_dict["pk_lin"]
Pknonlin = pk_dict["pk_nl"]
k = pk_dict["k"]
z = pk_dict["z"];

# println("Dimension of k points: ", size(k)[1])
# println("Dimension of Pklin: ", size(Pklin)[1])
# println("Dimension of Pknonlin: ", size(Pknonlin)[1])

#Interpolating the power spectrum
#Linear P(k)
# y has the same length as k, and is a logarithmic range from log10(first(k)) to log10(last(k))
y = LinRange(log10(first(k)),log10(last(k)), length(k))
# x has the same length as z, and is a linear range from first(z) to last(z)
x = LinRange(first(z), last(z), length(z))

# this creates an interpolation of the linear P(k) data. 
# the interpolatio is in log space because P(k) changes by many order or magnitude
InterpPmm = Interpolations.interpolate(log10.(Pklin),BSpline(Cubic(Line(OnGrid()))))
# this scales the interpolation to the x and y ranges defined above, 
# so that we can evaluate it at any (z, log10(k)) within those ranges
InterpPmm = scale(InterpPmm, (x, y))
# this allows us to extrapolate the interpolation outside of the defined x and y ranges
InterpPmm = Interpolations.extrapolate(InterpPmm, Line())

#Non-linear P(k) - similar to the linear P(k)
y = LinRange(log10(first(k)),log10(last(k)), length(k))
x = LinRange(first(z), last(z), length(z))
InterpPmm_nl = Interpolations.interpolate(log10.(Pknonlin),BSpline(Cubic(Line(OnGrid()))))
InterpPmm_nl = scale(InterpPmm_nl, x, y)
InterpPmm_nl = Interpolations.extrapolate(InterpPmm_nl, Line())

#Callables: these functions take in k, χ1, and χ2, 
# and return the square root of the product of the P(k) evaluated at those points.
power_spectrum(k, χ1, χ2) = @. sqrt(10^InterpPmm(z_of_χ(χ1),log10(k)) * 10^InterpPmm(z_of_χ(χ2),log10(k)))
power_spectrum_nl(k, χ1, χ2) = @. sqrt(10^InterpPmm_nl(z_of_χ(χ1),log10(k)) * 10^InterpPmm_nl(z_of_χ(χ2),log10(k)));

# plot(k, power_spectrum.(k, 1000.0, 1000.0), 
#      label="Linear P(k)", 
#      xscale=:log10, 
#      yscale=:log10, 
#      title=L"$P(k)$ at $z=0$", titlefontsize=20,
#      xlabel=L"$k \; (h/\mathrm{Mpc})$", 
#      ylabel=L"$P(k) \; ((\mathrm{Mpc}/h)^3)$", 
#      labelfontsize=15)
# plot!(k, power_spectrum_nl.(k, 1000.0, 1000.0), 
#       label="Non-linear P(k)", 
#       xscale=:log10, 
#       yscale=:log10,
#       size=(800,600),
#       legendfontsize=10)

# %% [markdown]
# get_clencurt_grid produces the node of Clenshaw-Curtis mapped on [$k_{min}$, $k_{max}$]. \
# get_clencurt_weights produces the corresponding quadrature weights scaled to the interval [-1,1]. \

# %%
Nz = n_chi
k_grid = Blast.get_clencurt_grid(kmin, kmax, Nz)
kp_grid = Blast.get_clencurt_grid(kmin, kmax, Nz)
kpp_grid = Blast.get_clencurt_grid(kmin, kmax, Nz)
w_k = Blast.get_clencurt_weights(kmin, kmax, Nz)
w_kp = Blast.get_clencurt_weights(kmin, kmax, Nz)
w_kpp = Blast.get_clencurt_weights(kmin, kmax, Nz);

# %%
Pk_grid = power_spectrum_nl.(k_grid, first(x), last(x))
Nk = length(k_grid)
Nℓ = length(ℓ)
weight_gal = w_k.^2 .* k_grid.^2 .* Pk_grid   
weight_shear = w_k .* k_grid.^(-2) .* Pk_grid   
weight_gal_shear = w_k .* Pk_grid   

abstract type AbstractProbe end
struct Galaxy <: AbstractProbe end
struct Shear <: AbstractProbe end
factorial_frac(ℓ) = (ℓ + 2.0) * (ℓ + 1.0) * ℓ * (ℓ - 1.0)
get_ell_prefactor(::Galaxy, ::Galaxy, ℓ) = @. (2 / π) * ones(length(ℓ))
get_ell_prefactor(::Galaxy, ::Shear,  ℓ) = @. (2 / π) * sqrt(factorial_frac(ℓ))
get_ell_prefactor(::Shear,  ::Galaxy, ℓ) = @. (2 / π) * sqrt(factorial_frac(ℓ))
get_ell_prefactor(::Shear,  ::Shear,  ℓ) = @. (2 / π) * factorial_frac(ℓ)
pref_gg = get_ell_prefactor(Galaxy(), Galaxy(), ℓ)
pref_gg = reduce(vcat, pref_gg)
pref_gs = get_ell_prefactor(Galaxy(), Shear(), ℓ)
pref_gs = reduce(vcat, pref_gs)
pref_gg = reduce(vcat, pref_gg)
pref_ss = get_ell_prefactor(Shear(), Shear(), ℓ)
pref_ss = reduce(vcat, pref_ss);

# %%
println("size of wktot (gal): ", size(weight_gal))
println("size of wktot (shear): ", size(weight_shear))
println("size of wktot (gal_shear): ", size(weight_gal_shear))
println("size of W_final_gal: ", size(W_final_gal))
println("size of W_final_shear: ", size(W_final_shear))
println("size of pref_gg: ", size(pref_gg))
println("size of pref_ss: ", size(pref_ss))
println("size of pref_gs: ", size(pref_gs))
# Out:
# size of wktot (gal): (96,)
# size of wktot (shear): (96,)
# size of wktot (gal_shear): (96,)
# size of W_final_gal: (100, 96, 96)
# size of W_final_shear: (100, 96, 96)
# size of pref_gg: (100,)
# size of pref_ss: (100,)
# size of pref_gs: (100,)

# %%
S_lkk_gg = zeros(Float64, size(W_final_gal, 3), size(W_final_gal, 3), length(ℓ))
@tullio S_lkk_gg[kp, kpp, li] = pref_gg[li] * weight_gal[k] * W_final_gal[li, k, kp] * W_final_gal[li, k, kpp]
S_lkk_ss = zeros(Float64, size(W_final_shear, 3), size(W_final_shear, 3), length(ℓ))
@tullio S_lkk_ss[kp, kpp, li] = pref_ss[li] * weight_shear[k] * W_final_shear[li, k, kp] * W_final_shear[li, k, kpp]
S_lkk_gs = zeros(Float64, size(W_final_shear, 3), size(W_final_gal, 3), length(ℓ))
@tullio S_lkk_gs[kp, kpp, li] = pref_gs[li] * weight_gal_shear[k] * W_final_shear[li, k, kp] * W_final_gal[li, k, kpp];

# %%
npzwrite(joinpath(quantity_subdir, "Sl/S_lkk_gg.npy"), S_lkk_gg)
npzwrite(joinpath(quantity_subdir, "Sl/S_lkk_ss.npy"), S_lkk_ss)
npzwrite(joinpath(quantity_subdir, "Sl/S_lkk_gs.npy"), S_lkk_gs);

# %%
println("Size of S_l (kp, kpp) (gal-gal):  ", size(S_lkk_gg))
println("Size of S_l (kp, kpp) (shear-shear):  ", size(S_lkk_ss))
println("Size of S_l (kp, kpp) (shear-gal):  ", size(S_lkk_gs))
# Out:
# Size of S_l (kp, kpp) (gal-gal):  (96, 96, 100)
# Size of S_l (kp, kpp) (shear-shear):  (96, 96, 100)
# Size of S_l (kp, kpp) (shear-gal):  (96, 96, 100)

# %%
# plot
i = 1
j = 1
p1 =  plot(ℓ, S_lkk_gg[i,j,:], label="Beyond BLAST", xlabel=L"\ell", ylabel=L"S_\ell", title=L"S_\ell(k_1, k_2)^{gg}")
p2 =  plot(ℓ, S_lkk_ss[i,j,:], label="Beyond BLAST", xlabel=L"\ell", ylabel=L"S_\ell", title=L"S_\ell(k_1, k_2)^{ss}")
p3 =  plot(ℓ, S_lkk_gs[i,j,:], label="Beyond BLAST", xlabel=L"\ell", ylabel=L"S_\ell", title=L"S_\ell(k_1, k_2)^{gs}")

plot(p1, p2, p3, layout = (1, 3), size=(2000, 600), titlefontsize=20, legendfontsize=10, margin = 10mm)

# %%
weight_kp = w_kp .* kp_grid   # pesi per k1 e k2
S_l_gg = zeros(Float64, length(ℓ))
@tullio S_l_gg[li] = weight_kp[kp] * S_lkk_gg[kp, kp, li]
S_l_ss = zeros(Float64, length(ℓ))
@tullio S_l_ss[li] = weight_kp[kp] * weight_kp[kpp] * S_lkk_ss[kp, kpp, li];
S_l_gs = zeros(Float64, length(ℓ))
@tullio S_l_gs[li] = weight_kp[kp] * weight_kp[kpp] * S_lkk_gs[kp, kpp, li];

# %%
npzwrite(joinpath(quantity_subdir, "Sl/S_l_gg.npy"), S_l_gg)
npzwrite(joinpath(quantity_subdir, "Sl/S_l_ss.npy"), S_l_ss)
npzwrite(joinpath(quantity_subdir, "Sl/S_l_gs.npy"), S_l_gs);

# %%
# plot
p1 =  plot(ℓ, S_l_gg, label="Beyond BLAST", xlabel=L"\ell", ylabel=L"S_\ell", title=L"S_\ell^{gg}", size = (1400,800))
savefig(joinpath(plot_subdir, "Sl_plots/S_l_plot_gg.png"))
p2 =  plot(ℓ, S_l_ss, label="Beyond BLAST", xlabel=L"\ell", ylabel=L"S_\ell", title=L"S_\ell^{ss}", size = (1400,800))
savefig(joinpath(plot_subdir, "Sl_plots/S_l_plot_ss.png"))
p3 =  plot(ℓ, S_l_gs, label="Beyond BLAST", xlabel=L"\ell", ylabel=L"S_\ell", title=L"S_\ell^{gs}", size = (1400,800))
savefig(joinpath(plot_subdir, "Sl_plots/S_l_plot_gs.png"))
plot(p1, p2, p3, layout = (1, 3), size=(2100, 500), titlefontsize=20, legendfontsize=10, margin = 10mm)

# %%
p1 = plot(
    ℓ,
    S_l_gg .* ℓ .* (ℓ .+ 1),
    label = "Beyond BLAST",
    xlabel = L"\ell",
    ylabel = L"\ell(\ell+1)S_\ell",
    title = L"\ell(\ell+1)S_\ell^{gg}",
    markersize=4,
    size = (700, 500),
    titlefontsize=20,
    labelfontsize=15
)
p2 = plot(
    ℓ,
    S_l_ss .* ℓ .* (ℓ .+ 1),
    label = "Beyond BLAST",
    xlabel = L"\ell",
    ylabel = L"\ell(\ell+1)S_\ell",
    title = L"\ell(\ell+1)S_\ell^{ss}",
    markersize=4,
    size = (700, 500),
    titlefontsize=20,
    labelfontsize=15
)
p3 = plot(
    ℓ,
    S_l_gs .* ℓ .* (ℓ .+ 1),
    label = "Beyond BLAST",
    xlabel = L"\ell",
    ylabel = L"\ell(\ell+1)S_\ell",
    title = L"\ell(\ell+1)S_\ell^{gs}",
    markersize=4,
    size = (700, 500),
    titlefontsize=20,
    labelfontsize=15
) 
plot(p1, p2, p3, layout = (1, 3), size=(2100, 500), titlefontsize=20, legendfontsize=10, margin = 10mm)

# %%
p1 = plot(ℓ, S_l_gg .* ℓ .* (ℓ .+ 1), label = L"N = $2^{15}+1$ with optimized $\tilde W$", xlabel = L"\ell", ylabel = L"\ell(\ell+1)S_\ell", title = L"\ell(\ell+1)S_\ell (gg)",
          markersize=4, size = (1400, 800), titlefontsize=20, labelfontsize=15, dpi = 200)
savefig(joinpath(output_dir, "plots/Sl_plots/S_l_plot_gg_per_l.png"))
p2 = plot(ℓ, S_l_ss .* ℓ .* (ℓ .+ 1), label = L"N = $2^{15}+1$ with optimized $\tilde W$", xlabel = L"\ell", ylabel = L"\ell(\ell+1)S_\ell", title = L"\ell(\ell+1)S_\ell (ss)",
          markersize=4, size = (1400, 800), titlefontsize=20, labelfontsize=15, dpi = 200)
savefig(joinpath(output_dir, "plots/Sl_plots/S_l_plot_ss_per_l.png"))
p3 = plot(ℓ, S_l_gs .* ℓ .* (ℓ .+ 1), label = L"N = $2^{15}+1$ with optimized $\tilde W$", xlabel = L"\ell", ylabel = L"\ell(\ell+1)S_\ell", title = L"\ell(\ell+1)S_\ell (gs)",
          markersize=4, size = (1400, 800), titlefontsize=20, labelfontsize=15, dpi = 200)
savefig(joinpath(output_dir, "plots/Sl_plots/S_l_plot_gs_per_l.png"))
# Out:
# "/Users/anvi/Desktop/cosmo/notebooks/out/runs/run_2026_06_20_120050/plots/Sl_plots/S_l_plot_gs_per_l.png"

# %%
params_run = Dict(
    "x_min" => x_min,
    "x_max" => x_max,
    "n_chi" => n_chi,
    "zmin" => zmin,
    "zmax" => zmax,
    "kmin" => kmin,
    "kmax" => kmax,
    "n_cheb" => n_cheb,
    "N" => N,
    "ℓ" => length(ℓ)
)

open(joinpath(output_dir, "config.json"), "w") do io
    JSON.print(io, params_run, 4) # Scrive il dizionario in formato JSON pulito
end

println("Data brought to safety in folder: ", output_dir)
# Out:
# Data brought to safety in folder: out/runs/run_2026_06_20_120050
